# %% [markdown]
# # Data Science and Algorithm

# %% [markdown]
# # Assigmnet-1

# %%
##Q1 Array operations
import array
from array import*

# %%
numbers= array("i",[1,2,3,4,5])
print(numbers)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
#(b)
sum=0

for i in range (0,len(numbers)):
    sum = sum + numbers[i]

print("sum of all numbers in array named numbers:",sum)
# Out:
# sum of all numbers in array named numbers: 15

# %%
#C
sum=0
for i in range(0,len(numbers)):
    sum = sum + numbers[i]
    average = sum //len(numbers)

print("average of numbers present in array named numbers :",average)
# Out:
# average of numbers present in array named numbers : 3

# %%
#D

print("maximum value present in array named numbers is :",max(numbers))
print("maximum value present in array named numbers is :",min(numbers))
# Out:
# maximum value present in array named numbers is : 5
# maximum value present in array named numbers is : 1

# %% [markdown]
# # Q2 Array manipulation

# %%
#(A)

Names = ["Pranav", "Gaurang","Aadya","Sabhyata","Shubhda","Vedant","Khushi","Mehak"]
print(Names)
# Out:
# ['Pranav', 'Gaurang', 'Aadya', 'Sabhyata', 'Shubhda', 'Vedant', 'Khushi', 'Mehak']

# %%
#(B)
Names.append("Pulkit")
Names.append("Aditya")
print(Names)
# Out:
# ['Pranav', 'Gaurang', 'Aadya', 'Sabhyata', 'Shubhda', 'Vedant', 'Khushi', 'Mehak', 'Pulkit', 'Aditya']

# %%
print(len(Names))
# Out:
# 9

# %%
#(C)

Names[5]="Akshita"
print(Names)
# Out:
# ['Pranav', 'Gaurang', 'Aadya', 'Sabhyata', 'Shubhda', 'Akshita', 'Khushi', 'Mehak', 'Pulkit', 'Aditya']

# %%
#(D)

Names.pop()
print(Names)
# Out:
# ['Pranav', 'Gaurang', 'Aadya', 'Sabhyata', 'Shubhda', 'Akshita', 'Khushi', 'Mehak', 'Pulkit']

# %%
print(len(Names))
# Out:
# 9

# %%
#(E)

print("Displaying final lsit names :",Names)
# Out:
# Displaying final lsit names : ['Pranav', 'Gaurang', 'Aadya', 'Sabhyata', 'Shubhda', 'Akshita', 'Khushi', 'Mehak', 'Pulkit']

# %% [markdown]
# # Q3 Searching In Array

# %%
#(A)

arr= array("i",[5,10,15,20,25,4,8,12,16,20,3,6,9,2,4])
print(arr)
# Out:
# array('i', [5, 10, 15, 20, 25, 4, 8, 12, 16, 20, 3, 6, 9, 2, 4])

# %%
#(B)

n=int(input("enter the value to check whether it is present in array or not :"))
print(n in arr)
# Out:
# enter the value to check whether it is present in array or not :10
# True

# %%
#(C)

n=int(input("enter the value to check whether it is present in array or not :"))

if n in arr:
    print("entered value is present in array named arr")
else:
    print("entered value is not present in array named arr")
# Out:
# enter the value to check whether it is present in array or not :5
# entered value is present in array named arr

# %% [markdown]
# # Q4 Array Sorting

# %%
a = array("i",[23,34,67,48,27,29,-1,0,16,91,22,87,53,61,-69])
print(arr)
# Out:
# array('i', [5, 10, 15, 20, 25, 4, 8, 12, 16, 20, 3, 6, 9, 2, 4])

# %%
#(B)
a.reverse()

# %%
print(a)
# Out:
# array('i', [-69, 61, 53, 87, 22, 91, 16, 0, -1, 29, 27, 48, 67, 34, 23])

# %%
#(C)
def dividing(array):
    n = len(a) // 2
    part1 = arr[:n]
    part2 = arr[n:]
    print("part1",part2)
    print("part2",part1)

arr = array("i",[23,34,67,48,27,29,-1,0,16,91,22,87,53,61,-69])
dividing(a)
# Out:
# part1 array('i', [12, 16, 20, 3, 6, 9, 2, 4])
# part2 array('i', [5, 10, 15, 20, 25, 4, 8])
